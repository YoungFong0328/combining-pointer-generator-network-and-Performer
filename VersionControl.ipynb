# %%
#TF and Keras Version Control
'''
1.Install Anaconda3 ver 2020.7
2.Install Visual Studio 2019 for c++ complier
3.Install CUDA 11.2.2
4.Download cuDnn 8.1.0
5.Copy CuDnn file to CUDA folder
6.Add CUDA bin, incude, x64 folder path to User Variables
'''
#
#Please follow the following instruction

# %%
# encoding: utf-8
# !pip install tensorflow==2.5.0 --upgrade --force-reinstall
#!pip install tensorflow
# Out:
# Collecting tensorflow==2.5.0
#   Using cached tensorflow-2.5.0-cp38-cp38-win_amd64.whl (422.6 MB)
# Collecting keras-nightly~=2.5.0.dev
#   Using cached keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
# Collecting tensorboard~=2.5
#   Using cached tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# Collecting protobuf>=3.9.2
#   Using cached protobuf-3.17.3-cp38-cp38-win_amd64.whl (909 kB)
# Collecting google-pasta~=0.2
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Processing c:\users\a2744\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73\wrapt-1.12.1-py3-none-any.whl
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp38-cp38-win_amd64.whl (2.7 MB)
# Collecting grpcio~=1.34.0
#   Using cached grpcio-1.34.1-cp38-cp38-win_amd64.whl (2.9 MB)
# Collecting astunparse~=1.6.3
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.13.0-py3-none-any.whl (132 kB)
# Collecting numpy~=1.19.2
#   Using cached numpy-1.19.5-cp38-cp38-win_amd64.whl (13.3 MB)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting opt-einsum~=3.3.0
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Processing c:\users\a2744\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501\termcolor-1.1.0-py3-none-any.whl
# Collecting wheel~=0.35
#   Using cached wheel-0.36.2-py2.py3-none-any.whl (35 kB)
# Collecting keras-preprocessing~=1.1.2
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.5-py2.py3-none-any.whl (18 kB)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.1-py3-none-any.whl (288 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting setuptools>=41.0.0
#   Downloading setuptools-57.4.0-py3-none-any.whl (819 kB)
# Collecting google-auth<2,>=1.6.3
#   Using cached google_auth-1.34.0-py2.py3-none-any.whl (152 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting idna<4,>=2.5; python_version >= "3"
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.4-py3-none-any.whl (36 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Using cached cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Installing collected packages: keras-nightly, cachetools, pyasn1, pyasn1-modules, setuptools, rsa, six, google-auth, certifi, urllib3, idna, charset-normalizer, requests, oauthlib, requests-oauthlib, google-auth-oauthlib, werkzeug, tensorboard-plugin-wit, protobuf, tensorboard-data-server, grpcio, wheel, markdown, numpy, absl-py, tensorboard, google-pasta, tensorflow-estimator, wrapt, typing-extensions, h5py, astunparse, flatbuffers, opt-einsum, gast, termcolor, keras-preprocessing, tensorflow
#   Attempting uninstall: keras-nightly
#     Found existing installation: keras-nightly 2.5.0.dev2021032900
#     Uninstalling keras-nightly-2.5.0.dev2021032900:
#       Successfully uninstalled keras-nightly-2.5.0.dev2021032900
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.2.2
#     Uninstalling cachetools-4.2.2:
#       Successfully uninstalled cachetools-4.2.2
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.4.8
#     Uninstalling pyasn1-0.4.8:
#       Successfully uninstalled pyasn1-0.4.8
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1-modules 0.2.8
#     Uninstalling pyasn1-modules-0.2.8:
#       Successfully uninstalled pyasn1-modules-0.2.8
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 49.2.0.post20200714
#     Uninstalling setuptools-49.2.0.post20200714:
#       Successfully uninstalled setuptools-49.2.0.post20200714
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.7.2
#     Uninstalling rsa-4.7.2:
#       Successfully uninstalled rsa-4.7.2
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.34.0
#     Uninstalling google-auth-1.34.0:
#       Successfully uninstalled google-auth-1.34.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.6.20
#     Uninstalling certifi-2020.6.20:
#       Successfully uninstalled certifi-2020.6.20
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.9
#     Uninstalling urllib3-1.25.9:
#       Successfully uninstalled urllib3-1.25.9
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
#   Attempting uninstall: oauthlib
#     Found existing installation: oauthlib 3.1.1
#     Uninstalling oauthlib-3.1.1:
#       Successfully uninstalled oauthlib-3.1.1
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 1.3.0
#     Uninstalling requests-oauthlib-1.3.0:
#       Successfully uninstalled requests-oauthlib-1.3.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.5
#     Uninstalling google-auth-oauthlib-0.4.5:
#       Successfully uninstalled google-auth-oauthlib-0.4.5
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: tensorboard-plugin-wit
#     Found existing installation: tensorboard-plugin-wit 1.8.0
#     Uninstalling tensorboard-plugin-wit-1.8.0:
#       Successfully uninstalled tensorboard-plugin-wit-1.8.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.6.1
#     Uninstalling tensorboard-data-server-0.6.1:
#       Successfully uninstalled tensorboard-data-server-0.6.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.34.1
#     Uninstalling grpcio-1.34.1:
#       Successfully uninstalled grpcio-1.34.1
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.36.2
#     Uninstalling wheel-0.36.2:
#       Successfully uninstalled wheel-0.36.2
#   Attempting uninstall: markdown
#     Found existing installation: Markdown 3.3.4
#     Uninstalling Markdown-3.3.4:
#       Successfully uninstalled Markdown-3.3.4
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.13.0
#     Uninstalling absl-py-0.13.0:
#       Successfully uninstalled absl-py-0.13.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Attempting uninstall: google-pasta
#     Found existing installation: google-pasta 0.2.0
#     Uninstalling google-pasta-0.2.0:
#       Successfully uninstalled google-pasta-0.2.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.12.1
#     Uninstalling wrapt-1.12.1:
#       Successfully uninstalled wrapt-1.12.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.2
#     Uninstalling typing-extensions-3.7.4.2:
#       Successfully uninstalled typing-extensions-3.7.4.2
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: astunparse
#     Found existing installation: astunparse 1.6.3
#     Uninstalling astunparse-1.6.3:
#       Successfully uninstalled astunparse-1.6.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt-einsum 3.3.0
#     Uninstalling opt-einsum-3.3.0:
#       Successfully uninstalled opt-einsum-3.3.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 1.1.0
#     Uninstalling termcolor-1.1.0:
#       Successfully uninstalled termcolor-1.1.0
#   Attempting uninstall: keras-preprocessing
#     Found existing installation: Keras-Preprocessing 1.1.2
#     Uninstalling Keras-Preprocessing-1.1.2:
#       Successfully uninstalled Keras-Preprocessing-1.1.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.5.0
#     Uninstalling tensorflow-2.5.0:
#       Successfully uninstalled tensorflow-2.5.0
# Successfully installed absl-py-0.13.0 astunparse-1.6.3 cachetools-4.2.2 certifi-2021.5.30 charset-normalizer-2.0.4 flatbuffers-1.12 gast-0.4.0 google-auth-1.34.0 google-auth-oauthlib-0.4.5 google-pasta-0.2.0 grpcio-1.34.1 h5py-3.1.0 idna-3.2 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.4 numpy-1.19.5 oauthlib-3.1.1 opt-einsum-3.3.0 protobuf-3.17.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.26.0 requests-oauthlib-1.3.0 rsa-4.7.2 setuptools-57.4.0 six-1.15.0 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 termcolor-1.1.0 typing-extensions-3.7.4.3 urllib3-1.26.6 werkzeug-2.0.1 wheel-0.36.2 wrapt-1.12.1

# %%
# !pip install tensorflow-gpu==2.5.0
# Out:
# Collecting tensorflow-gpu==2.5.0
#   Downloading tensorflow_gpu-2.5.0-cp38-cp38-win_amd64.whl (422.6 MB)
# Requirement already satisfied: wheel~=0.35 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (0.36.2)
# Requirement already satisfied: six~=1.15.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (1.15.0)
# Requirement already satisfied: absl-py~=0.10 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (0.13.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (3.1.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (2.5.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (0.4.0)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (1.34.1)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (0.2.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (3.3.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (1.1.2)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (2.5.0.dev2021032900)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (1.19.5)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (3.17.3)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (2.5.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (3.7.4.3)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\a2744\anaconda3\lib\site-packages (from tensorflow-gpu==2.5.0) (1.12.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\a2744\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.0) (2.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.0) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.0) (1.8.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\a2744\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.0) (1.34.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\a2744\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.0) (0.4.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\a2744\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.0) (2.26.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\a2744\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow-gpu==2.5.0) (3.3.4)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\a2744\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu==2.5.0) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\a2744\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu==2.5.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\a2744\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu==2.5.0) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\a2744\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow-gpu==2.5.0) (1.3.0)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\a2744\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\a2744\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.0) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\a2744\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.0) (1.26.6)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\a2744\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu==2.5.0) (3.2)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\a2744\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu==2.5.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\a2744\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow-gpu==2.5.0) (3.1.1)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.5.0

# %%
#!pip install keras --user --upgrade --force-reinstall for getting right version
# !pip install keras==2.4.3
import keras
print(keras.__version__)
# Out:
# Requirement already satisfied: keras==2.4.3 in c:\users\a2744\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: pyyaml in c:\users\a2744\anaconda3\lib\site-packages (from keras==2.4.3) (5.3.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\a2744\anaconda3\lib\site-packages (from keras==2.4.3) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in c:\users\a2744\anaconda3\lib\site-packages (from keras==2.4.3) (1.5.0)
# Requirement already satisfied: h5py in c:\users\a2744\anaconda3\lib\site-packages (from keras==2.4.3) (3.1.0)
# 2.5.0

# %%
#keep doing that
# !pip install keras==2.5.0rc0
import keras
print(keras.__version__)
#stop at here
# Out:
# Collecting keras==2.5.0rc0
#   Using cached keras-2.5.0rc0-py2.py3-none-any.whl (1.2 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.5.0rc0
# 2.5.0

# %%
#reset and run this
#!pip install keras --user --upgrade --force-reinstall
# !pip install keras==2.4.3
import keras
print("Keras ver: ", keras.__version__)
# Out:
# Requirement already satisfied: keras==2.4.3 in c:\users\a2744\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\a2744\anaconda3\lib\site-packages (from keras==2.4.3) (1.19.5)
# Requirement already satisfied: h5py in c:\users\a2744\anaconda3\lib\site-packages (from keras==2.4.3) (3.1.0)
# Requirement already satisfied: pyyaml in c:\users\a2744\anaconda3\lib\site-packages (from keras==2.4.3) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\a2744\anaconda3\lib\site-packages (from keras==2.4.3) (1.5.0)
# Keras ver:  2.4.3

# %%
#requir packages
# !pip install nltk
# !pip install keras-pos-embd
# !pip install keras-multi-head
# !pip install keras-layer-normalization
# !pip install keras-embed-sim

# !pip install scikit-learn
# Out:
# Collecting keras-pos-embd
#   Downloading keras-pos-embd-0.12.0.tar.gz (6.0 kB)
# Requirement already satisfied: numpy in c:\users\w.r_chen\anaconda3\lib\site-packages (from keras-pos-embd) (1.19.5)
# Requirement already satisfied: Keras in c:\users\w.r_chen\anaconda3\lib\site-packages (from keras-pos-embd) (2.4.3)
# Requirement already satisfied: h5py in c:\users\w.r_chen\anaconda3\lib\site-packages (from Keras->keras-pos-embd) (3.1.0)
# Requirement already satisfied: pyyaml in c:\users\w.r_chen\anaconda3\lib\site-packages (from Keras->keras-pos-embd) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in c:\users\w.r_chen\anaconda3\lib\site-packages (from Keras->keras-pos-embd) (1.5.0)
# Building wheels for collected packages: keras-pos-embd
#   Building wheel for keras-pos-embd (setup.py): started
#   Building wheel for keras-pos-embd (setup.py): finished with status 'done'
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.12.0-py3-none-any.whl size=7470 sha256=b87449dd43c3dd1aca3225c89ec9b2eca5842d88a32cddd79774f359ebcec9f6
#   Stored in directory: c:\users\w.r_chen\appdata\local\pip\cache\wheels\c0\b7\8f\ef4ba34a4f7e8154c0837151d60744a5521bbd2545282a6f08
# Successfully built keras-pos-embd
# Installing collected packages: keras-pos-embd
# Successfully installed keras-pos-embd-0.12.0
# Collecting keras-multi-head
#   Downloading keras-multi-head-0.28.0.tar.gz (14 kB)
# Requirement already satisfied: numpy in c:\users\w.r_chen\anaconda3\lib\site-packages (from keras-multi-head) (1.19.5)
# Requirement already satisfied: Keras in c:\users\w.r_chen\anaconda3\lib\site-packages (from keras-multi-head) (2.4.3)
# Collecting keras-self-attention>=0.50.0
#   Downloading keras-self-attention-0.50.0.tar.gz (12 kB)
# Requirement already satisfied: h5py in c:\users\w.r_chen\anaconda3\lib\site-packages (from Keras->keras-multi-head) (3.1.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\w.r_chen\anaconda3\lib\site-packages (from Keras->keras-multi-head) (1.5.0)
# Requirement already satisfied: pyyaml in c:\users\w.r_chen\anaconda3\lib\site-packages (from Keras->keras-multi-head) (5.3.1)
# Building wheels for collected packages: keras-multi-head, keras-self-attention
#   Building wheel for keras-multi-head (setup.py): started
#   Building wheel for keras-multi-head (setup.py): finished with status 'done'
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.28.0-py3-none-any.whl size=15560 sha256=0c1f9e326a4a889951ceffc46586dedce2766a1580b63a69537fbcc30a4be8b6
#   Stored in directory: c:\users\w.r_chen\appdata\local\pip\cache\wheels\eb\cd\c0\b5cc0768484f702e7a5a9a54854821159947043217990cc025
#   Building wheel for keras-self-attention (setup.py): started
#   Building wheel for keras-self-attention (setup.py): finished with status 'done'
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.50.0-py3-none-any.whl size=19415 sha256=3a8fe8eda8e6f5bbe38f19e3708d64842fcf3cfc38a04916ae747d40717d5574
#   Stored in directory: c:\users\w.r_chen\appdata\local\pip\cache\wheels\dc\33\4c\0429815c6d822ce17fc32b0809659e4a083b7e05fc26699450
# Successfully built keras-multi-head keras-self-attention
# Installing collected packages: keras-self-attention, keras-multi-head
# Successfully installed keras-multi-head-0.28.0 keras-self-attention-0.50.0
# Collecting keras-embed-sim
#   Downloading keras-embed-sim-0.9.0.tar.gz (4.1 kB)
# Requirement already satisfied: numpy in c:\users\w.r_chen\anaconda3\lib\site-packages (from keras-embed-sim) (1.19.5)
# Requirement already satisfied: Keras in c:\users\w.r_chen\anaconda3\lib\site-packages (from keras-embed-sim) (2.4.3)
# Requirement already satisfied: scipy>=0.14 in c:\users\w.r_chen\anaconda3\lib\site-packages (from Keras->keras-embed-sim) (1.5.0)
# Requirement already satisfied: pyyaml in c:\users\w.r_chen\anaconda3\lib\site-packages (from Keras->keras-embed-sim) (5.3.1)
# Requirement already satisfied: h5py in c:\users\w.r_chen\anaconda3\lib\site-packages (from Keras->keras-embed-sim) (3.1.0)
# Building wheels for collected packages: keras-embed-sim
#   Building wheel for keras-embed-sim (setup.py): started
#   Building wheel for keras-embed-sim (setup.py): finished with status 'done'
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.9.0-py3-none-any.whl size=4506 sha256=46f7a138613b4a43865f30bd582a5c49016f157e9a631268c6336323105329c0
#   Stored in directory: c:\users\w.r_chen\appdata\local\pip\cache\wheels\27\20\08\4d24796fdf8219bdd7c108bd7aa94b83bbe2500bd695a9f710
# Successfully built keras-embed-sim
# Installing collected packages: keras-embed-sim
# Successfully installed keras-embed-sim-0.9.0
